# %% [markdown]
# <a href="https://colab.research.google.com/github/datascience-uniandes/data-quality-tutorial/blob/master/data-quality-tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Quality tutorial
#
# MINE-4101: Applied Data Science
# Univerisdad de los Andes
#
# Dataset: Homicides Colombia
# Source: [datos.gov.co](datos.gov.co)
#
# Last update: September, 2022

# %% [markdown]
# Completed by:
# Diego Peña

# %%
# This line is commented because this notebook was completed in a local environment
#!pip install pylev

# %%
# Importing required libraries

import re
from random import randint
from datetime import datetime

import numpy as np
import pandas as pd

import pylev

# %%
# Parameter for showing all columns when printing a dataframe
pd.set_option('display.max_columns', None)

# %%
# Loading data
homicides_df = pd.read_csv("./data/homicides.csv")

# %%
# Printing the dataset dimensions
homicides_df.shape
# Out:
# (12400, 22)

# %%
# Printing column data types
homicides_df.dtypes
# Out:
# FECHA                 object
# DEPARTAMENTO          object
# MUNICIPIO             object
# DIA                   object
# HORA                  object
# BARRIO                object
# ZONA                  object
# CLASE DE SITIO        object
# ARMA O MEDIO          object
# MOVIL VICTIMA         object
# MOVIL AGRESOR         object
# EDAD                 float64
# GENERO                object
# ESTADO CIVIL          object
# CLASE EMPLEADO        object
# PROFESION             object
# ESCOLARIDAD           object
# PAIS NACE             object
# CODIGO DANE          float64
# AÑO DE NACIMIENTO    float64
# CÉDULA                object
# CORREO                object
# dtype: object

# %%
homicides_df.head()
# Out:
#                     FECHA DEPARTAMENTO      MUNICIPIO     DIA   HORA  \
# 0  01/01/2021 12:00:00 AM    ANTIOQUIA          AMAGÁ  Jueves   6:00
# 1  01/01/2021 12:00:00 AM    ANTIOQUIA        BARBOSA  Jueves   9:00
# 2  01/01/2021 12:00:00 AM    ANTIOQUIA       EL BAGRE  Jueves  19:00
# 3  01/01/2021 12:00:00 AM    ANTIOQUIA         JARDÍN  Jueves  11:20
# 4  01/01/2021 12:00:00 AM    ANTIOQUIA  MEDELLÍN (CT)   Juees  15:00
#
#                      BARRIO    ZONA                      CLASE DE SITIO  \
# 0                 EL VOLCAN   RURAL                              TIENDA
# 1            VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2             PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4  PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
#
#    ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 0   ARMA BLANCA         A PIE         A PIE  44.0  MASCULINO       CASADO
# 1   ARMA BLANCA         A PIE         A PIE  30.0  MASCULINO      SOLTERO
# 2   ARMA BLANCA         A PIE         A PIE  33.0  MASCULINO  UNION LIBRE
# 3   ARMA BLANCA         A PIE         A PIE  40.0  MASCULINO       CASADO
# 4  CONTUNDENTES         A PIE         A PIE  66.0  MASCULINO  UNION LIBRE
#
#   CLASE EMPLEADO     PROFESION ESCOLARIDAD     PAIS NACE  CODIGO DANE  \
# 0  INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA    5030000.0
# 1    DESEMPLEADO  NO REPORTADO  SECUNDARIA  NO REPORTADO    5079000.0
# 2     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5250000.0
# 3     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5364000.0
# 4    DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA    5001000.0
#
#    AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 0             1971.0  42-908  agbnqg2122@unidatos.edu.co
# 1             1985.0  15-183        rbkeui3584@gmail.com
# 2             1982.0  84-786  aorkhf9155@unidatos.edu.co
# 3             1975.0  31-289  dhtemr6623@unidatos.edu.co
# 4             1949.0  66-363  artatj9268@unidatos.edu.co

# %%
# Creating a lambda expression for datetime parsing
dateparse = lambda x: datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")

# %%
# Applying the validation to all values in column
homicides_df["FECHA"].apply(dateparse)

# IT IS EXPECTED TO HAVE AN ERROR INTENTIONALLY
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24448/1457432974.py in <module>
#       1 # Applying the validation to all values in column
# ----> 2 homicides_df["FECHA"].apply(dateparse)
#       3
#       4 # IT IS EXPECTED TO HAVE AN ERROR INTENTIONALLY
#
# c:\Users\sword\VirtualEnvironments\MachineLearning\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# c:\Users\sword\VirtualEnvironments\MachineLearning\lib\site-packages\pandas\core\apply.py in apply(self)
#    1080             return self.apply_str()
#    1081
# -> 1082         return self.apply_standard()
#    1083
#    1084     def agg(self):
#
# c:\Users\sword\VirtualEnvironments\MachineLearning\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1135                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136                 # "Callable[[Any], Any]"
# -> 1137                 mapped = lib.map_infer(
#    1138                     values,
#    1139                     f,  # type: ignore[arg-type]
#
# c:\Users\sword\VirtualEnvironments\MachineLearning\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_24448/513277637.py in <lambda>(x)
#       1 # Creating a lambda expression for datetime parsing
# ----> 2 dateparse = lambda x: datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")
#
# ~\AppData\Local\Programs\Python\Python39\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~\AppData\Local\Programs\Python\Python39\lib\_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
#
# ValueError: time data 'TOTAL' does not match format '%m/%d/%Y %H:%M:%S %p'

# %%
# Creating a function for validating which value is causing the previous error
def error_in_format(x):
    try:
        datetime.strptime(x, "%m/%d/%Y %H:%M:%S %p")
        return False
    except:
        return True

# %%
# Using the function for validation
homicides_df.loc[homicides_df["FECHA"].apply(error_in_format)]

# THE LAST ROW IS CAUSING THE ERROR
# Out:
#        FECHA DEPARTAMENTO MUNICIPIO  DIA HORA BARRIO ZONA CLASE DE SITIO  \
# 12399  TOTAL          NaN       NaN  NaN  NaN    NaN  NaN            NaN
#
#       ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD GENERO ESTADO CIVIL  \
# 12399          NaN           NaN           NaN   NaN    NaN          NaN
#
#       CLASE EMPLEADO PROFESION ESCOLARIDAD PAIS NACE  CODIGO DANE  \
# 12399            NaN       NaN         NaN       NaN          NaN
#
#        AÑO DE NACIMIENTO CÉDULA CORREO
# 12399                NaN    NaN    NaN

# %%
# Deleting a row by its index
homicides_df.drop(12399, inplace = True)

# %%
# Trying to parse the datetime string again
homicides_df["FECHA"] = homicides_df["FECHA"].apply(dateparse)

# %%
# Counting homicides by hour
homicides_df["FECHA"].dt.hour.value_counts()

# All datetime hour parts are the same
# Out:
# 12    12399
# Name: FECHA, dtype: int64

# %%
# The homicide hour is available in a different column!
# Merging both columns
homicides_df["FECHA"] = homicides_df["FECHA"].astype(str).apply(lambda x: x[:11]) + homicides_df["HORA"]

# %%
del homicides_df["HORA"]

# %%
homicides_df["FECHA"].head()
# Out:
# 0     2021-01-01 6:00
# 1     2021-01-01 9:00
# 2    2021-01-01 19:00
# 3    2021-01-01 11:20
# 4    2021-01-01 15:00
# Name: FECHA, dtype: object

# %%
# Making a new expression for datetime parsing
dateparse = lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M")

# %%
# Applying the expression
homicides_df["FECHA"] = homicides_df["FECHA"].apply(dateparse)

# %%
homicides_df.dtypes
# Out:
# FECHA                datetime64[ns]
# DEPARTAMENTO                 object
# MUNICIPIO                    object
# DIA                          object
# BARRIO                       object
# ZONA                         object
# CLASE DE SITIO               object
# ARMA O MEDIO                 object
# MOVIL VICTIMA                object
# MOVIL AGRESOR                object
# EDAD                        float64
# GENERO                       object
# ESTADO CIVIL                 object
# CLASE EMPLEADO               object
# PROFESION                    object
# ESCOLARIDAD                  object
# PAIS NACE                    object
# CODIGO DANE                 float64
# AÑO DE NACIMIENTO           float64
# CÉDULA                       object
# CORREO                       object
# dtype: object

# %%
homicides_df.head()
# Out:
#                 FECHA DEPARTAMENTO      MUNICIPIO     DIA  \
# 0 2021-01-01 06:00:00    ANTIOQUIA          AMAGÁ  Jueves
# 1 2021-01-01 09:00:00    ANTIOQUIA        BARBOSA  Jueves
# 2 2021-01-01 19:00:00    ANTIOQUIA       EL BAGRE  Jueves
# 3 2021-01-01 11:20:00    ANTIOQUIA         JARDÍN  Jueves
# 4 2021-01-01 15:00:00    ANTIOQUIA  MEDELLÍN (CT)   Juees
#
#                      BARRIO    ZONA                      CLASE DE SITIO  \
# 0                 EL VOLCAN   RURAL                              TIENDA
# 1            VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2             PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4  PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
#
#    ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 0   ARMA BLANCA         A PIE         A PIE  44.0  MASCULINO       CASADO
# 1   ARMA BLANCA         A PIE         A PIE  30.0  MASCULINO      SOLTERO
# 2   ARMA BLANCA         A PIE         A PIE  33.0  MASCULINO  UNION LIBRE
# 3   ARMA BLANCA         A PIE         A PIE  40.0  MASCULINO       CASADO
# 4  CONTUNDENTES         A PIE         A PIE  66.0  MASCULINO  UNION LIBRE
#
#   CLASE EMPLEADO     PROFESION ESCOLARIDAD     PAIS NACE  CODIGO DANE  \
# 0  INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA    5030000.0
# 1    DESEMPLEADO  NO REPORTADO  SECUNDARIA  NO REPORTADO    5079000.0
# 2     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5250000.0
# 3     AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA    5364000.0
# 4    DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA    5001000.0
#
#    AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 0             1971.0  42-908  agbnqg2122@unidatos.edu.co
# 1             1985.0  15-183        rbkeui3584@gmail.com
# 2             1982.0  84-786  aorkhf9155@unidatos.edu.co
# 3             1975.0  31-289  dhtemr6623@unidatos.edu.co
# 4             1949.0  66-363  artatj9268@unidatos.edu.co

# %%
# Creating a dictionary representing the valid departments for Colombia
departments_list = ['ANTIOQUIA', 'ATLÁNTICO', 'BOLÍVAR', 'BOYACÁ', 'CALDAS', 'CAQUETÁ',
       'CASANARE', 'CAUCA', 'CESAR', 'CHOCÓ', 'CÓRDOBA', 'META',
       'CUNDINAMARCA', 'HUILA', 'MAGDALENA', 'NARIÑO', 'PUTUMAYO',
       'RISARALDA', 'SANTANDER', 'SUCRE', 'TOLIMA', 'VALLE',
       'NORTE DE SANTANDER', 'GUAJIRA', 'QUINDÍO', 'SAN ANDRÉS Y PROVIDENCIA', 'ARAUCA',
       'GUAINÍA', 'VICHADA', 'VAUPÉS', 'GUAVIARE', 'AMAZONAS']

# %%
# Finding values not matching with the dictionary
homicides_df.loc[~homicides_df["DEPARTAMENTO"].isin(departments_list), "DEPARTAMENTO"].unique()
# Out:
# array(['SAN ANDRÉS', 'N. DE SANTANDER'], dtype=object)

# %% [markdown]
# <span style="color:red">TODO: Replace the values identified as error to a valid value from the dictionary</span>
#
# <span style="color:red">Hint: You can use the replace() pandas function</span>

# %%
homicides_df.DEPARTAMENTO.replace("SAN ANDRÉS", "SAN ANDRÉS Y PROVIDENCIA", inplace=True)
homicides_df[homicides_df["DEPARTAMENTO"] == "SAN ANDRÉS Y PROVIDENCIA"]
# Out:
#                     FECHA              DEPARTAMENTO        MUNICIPIO  \
# 212   2021-01-04 19:48:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 1714  2021-02-21 22:39:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 3148  2021-04-05 02:30:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 3149  2021-04-05 02:30:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 3927  2021-04-29 01:06:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 4183  2021-05-07 12:30:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 4254  2021-05-09 16:25:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 4298  2021-05-10 17:40:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 4609  2021-05-19 20:50:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 4768  2021-05-24 23:20:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 6131  2021-06-30 21:14:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 7485  2021-08-09 23:02:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 9283  2021-10-04 01:34:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 11130 2021-11-29 22:30:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 11131 2021-11-29 22:30:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 11549 2021-12-10 12:47:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 11664 2021-12-13 22:30:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
# 11760 2021-12-16 19:20:00  SAN ANDRÉS Y PROVIDENCIA  SAN ANDRÉS (CT)
#
#              DIA                   BARRIO    ZONA       CLASE DE SITIO  \
# 212      Domingo              FLOWER HILL  URBANA        VIAS PUBLICAS
# 1714      Sábado                LOMA COVE   RURAL        VIAS PUBLICAS
# 3148     Domingo  SECTOR COLISEO SAN LUIS  URBANA        VIAS PUBLICAS
# 3149     Domingo  SECTOR COLISEO SAN LUIS  URBANA        VIAS PUBLICAS
# 3927   Miércoles          SECTOR ELSY BAR  URBANA        VIAS PUBLICAS
# 4183      Jueves          BARRIO MODELO I  URBANA        VIAS PUBLICAS
# 4254      Sábado          BARRIO LA UNION  URBANA        VIAS PUBLICAS
# 4298     Dominog      BARRIO NUEVA GUINEA  URBANA        VIAS PUBLICAS
# 4609      Martes          BARRIO LA UNION  URBANA        VIAS PUBLICAS
# 4768     Domingo          BARRIO ALMENDRO  URBANA        VIAS PUBLICAS
# 6131      Martes        BARRIO RACK HOLLE  URBANA        VIAS PUBLICAS
# 7485     Domingo          BARRIO MODELO I  URBANA        VIAS PUBLICAS
# 9283     Domungo          BARRIO TABLITAS  URBANA  CASAS DE HABITACION
# 11130    Dominog             BARRIO COCAL  URBANA        VIAS PUBLICAS
# 11131    Domingo           BARRIO SANTANA  URBANA        VIAS PUBLICAS
# 11549      Juees      BARRIO SCHOOL HOUSE  URBANA        VIAS PUBLICAS
# 11664    Domingo            BARRIO OBRERO  URBANA        VIAS PUBLICAS
# 11760  Miércoles             LOMA BARRACK  URBANA        VIAS PUBLICAS
#
#         ARMA O MEDIO          MOVIL VICTIMA          MOVIL AGRESOR  EDAD  \
# 212    ARMA DE FUEGO  CONDUCTOR MOTOCICLETA   PASAJERO MOTOCICLETA  52.0
# 1714   ARMA DE FUEGO  CONDUCTOR MOTOCICLETA   PASAJERO MOTOCICLETA  42.0
# 3148   ARMA DE FUEGO   PASAJERO MOTOCICLETA   PASAJERO MOTOCICLETA  19.0
# 3149   ARMA DE FUEGO   PASAJERO MOTOCICLETA   PASAJERO MOTOCICLETA  19.0
# 3927   ARMA DE FUEGO  CONDUCTOR MOTOCICLETA   PASAJERO MOTOCICLETA  24.0
# 4183   ARMA DE FUEGO  CONDUCTOR MOTOCICLETA   PASAJERO MOTOCICLETA  49.0
# 4254   ARMA DE FUEGO                  A PIE   PASAJERO MOTOCICLETA  44.0
# 4298   ARMA DE FUEGO                  A PIE                  A PIE  21.0
# 4609   ARMA DE FUEGO  CONDUCTOR MOTOCICLETA  CONDUCTOR MOTOCICLETA  27.0
# 4768   ARMA DE FUEGO                  A PIE                  A PIE  19.0
# 6131   ARMA DE FUEGO                  A PIE   PASAJERO MOTOCICLETA  23.0
# 7485   ARMA DE FUEGO                  A PIE                  A PIE  26.0
# 9283   ARMA DE FUEGO   PASAJERO MOTOCICLETA                  A PIE  36.0
# 11130  ARMA DE FUEGO                  A PIE                  A PIE  29.0
# 11131  ARMA DE FUEGO                  A PIE                  A PIE  38.0
# 11549  ARMA DE FUEGO  CONDUCTOR MOTOCICLETA                  A PIE  37.0
# 11664  ARMA DE FUEGO                  A PIE   PASAJERO MOTOCICLETA  31.0
# 11760  ARMA DE FUEGO                  A PIE   PASAJERO MOTOCICLETA  49.0
#
#           GENERO ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD  \
# 212    MASCULINO  UNION LIBRE     AFRODESCENDIENTE  NO REPORTADO  SECUNDARIA
# 1714   MASCULINO      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 3148   MASCULINO      SOLTERO     AFRODESCENDIENTE  NO REPORTADO  SECUNDARIA
# 3149   MASCULINO      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 3927   MASCULINO      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 4183   MASCULINO      SOLTERO          DESEMPLEADO  NO REPORTADO    PRIMARIA
# 4254   MASCULINO  UNION LIBRE        INDEPENDIENTE  NO REPORTADO     TECNICO
# 4298   MASCULINO      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 4609   MASCULINO  UNION LIBRE          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 4768   MASCULINO      SOLTERO          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 6131   MASCULINO      SOLTERO          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 7485   MASCULINO  UNION LIBRE  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 9283    FEMENINO  UNION LIBRE          AMA DE CASA  NO REPORTADO  SECUNDARIA
# 11130  MASCULINO      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 11131   FEMENINO  UNION LIBRE  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 11549  MASCULINO  UNION LIBRE  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA
# 11664  MASCULINO  UNION LIBRE          DESEMPLEADO  NO REPORTADO  SECUNDARIA
# 11760  MASCULINO  UNION LIBRE          COMERCIANTE  NO REPORTADO  SECUNDARIA
#
#       PAIS NACE  CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA  \
# 212    COLOMBIA   88001000.0             1963.0  35-133
# 1714   COLOMBIA   88001000.0             1973.0  87-308
# 3148   COLOMBIA   88001000.0             1996.0  24-969
# 3149   COLOMBIA   88001000.0             1996.0  56-082
# 3927   COLOMBIA   88001000.0             1991.0  32-788
# 4183   COLOMBIA   88001000.0             1966.0  16-428
# 4254   COLOMBIA   88001000.0             1971.0  31-221
# 4298   COLOMBIA   88001000.0             1994.0  15-101
# 4609   COLOMBIA   88001000.0             1988.0  89-566
# 4768   COLOMBIA   88001000.0             1996.0  53-271
# 6131   COLOMBIA   88001000.0             1992.0  45-509
# 7485   COLOMBIA   88001000.0             1989.0  98-980
# 9283   COLOMBIA   88001000.0             1979.0  60-114
# 11130  COLOMBIA   88001000.0             1986.0  42-846
# 11131  COLOMBIA   88001000.0             1977.0  51-300
# 11549  COLOMBIA   88001000.0             1978.0  30-627
# 11664  COLOMBIA   88001000.0             1984.0  84-305
# 11760  COLOMBIA   88001000.0             1966.0  69-085
#
#                            CORREO
# 212    correo9894@colombia.gov.co
# 1714   ldeggo3300@unidatos.edu.co
# 3148         cepfdi6722@gmail.com
# 3149    correo184@unidatos.edu.co
# 3927         tmqbmi8077@gmail.com
# 4183   kuhcmq3124@unidatos.edu.co
# 4254         hpjdtm7583@gmail.com
# 4298   ftlqjb5716@unidatos.edu.co
# 4609   qsgogp9303@unidatos.edu.co
# 4768         babgcj7330@gmail.com
# 6131   raibqq2955@unidatos.edu.co
# 7485         pdirgd1985@gmail.com
# 9283   psfbai7011@unidatos.edu.co
# 11130        pikarp3727@gmail.com
# 11131  dpcadg3401@unidatos.edu.co
# 11549   correo420@unidatos.edu.co
# 11664  correo8267@colombia.gov.co
# 11760        srcjbc3281@gmail.com

# %%
# Detecting duplicates by "CÉDULA" column
duplicates_by_cedula = homicides_df.loc[homicides_df["CÉDULA"].duplicated(keep = False)]

# %%
duplicates_by_cedula.shape
# Out:
# (1627, 21)

# %%
# Showing some examples
duplicates_by_cedula.sort_values("CÉDULA", ascending = True).head(6)
# Out:
#                     FECHA DEPARTAMENTO      MUNICIPIO      DIA  \
# 4041  2021-05-03 23:30:00        CAUCA       EL TAMBO  Domingo
# 3810  2021-04-26 03:00:00    ANTIOQUIA   SAN JERÓNIMO  Domingo
# 693   2021-01-19 05:30:00    ANTIOQUIA         SALGAR    Lunes
# 10796 2021-11-20 03:00:00        VALLE      CALI (CT)  Viernes
# 2386  2021-03-14 02:00:00         META  FUENTE DE ORO   Sábado
# 138   2021-01-02 06:20:00        CAUCA         SOTARA  Viernes
#
#                     BARRIO    ZONA                      CLASE DE SITIO  \
# 4041           LA VICTORIA   RURAL         BARES, CANTINAS Y SIMILARES
# 3810              LA PLAYA  URBANA  HOTELES, RESIDENCIAS, Y SIMILARES.
# 693              LA HABANA  URBANA                       VIAS PUBLICAS
# 10796   POTRERO GRANDE E21  URBANA                       VIAS PUBLICAS
# 2386   VEREDA PUERTO NUEVO   RURAL         BARES, CANTINAS Y SIMILARES
# 138                 CENTRO   RURAL                       VIAS PUBLICAS
#
#              ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 4041        ARMA DE FUEGO         A PIE         A PIE  45.0  MASCULINO
# 3810   CUERDA/SOGA/CADENA         A PIE         A PIE  25.0  MASCULINO
# 693         ARMA DE FUEGO         A PIE         A PIE  58.0  MASCULINO
# 10796       ARMA DE FUEGO         A PIE         A PIE  21.0  MASCULINO
# 2386          ARMA BLANCA         A PIE         A PIE  42.0  MASCULINO
# 138           ARMA BLANCA         A PIE         A PIE  22.0  MASCULINO
#
#       ESTADO CIVIL       CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  \
# 4041   UNION LIBRE           AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA
# 3810       SOLTERO        INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA
# 693        SOLTERO           AGRICULTOR  NO REPORTADO    PRIMARIA  COLOMBIA
# 10796      SOLTERO  EMPLEADO PARTICULAR  NO REPORTADO  SECUNDARIA  COLOMBIA
# 2386       SOLTERO        INDEPENDIENTE  NO REPORTADO    PRIMARIA  COLOMBIA
# 138        SOLTERO    EMPLEADO EJERCITO  NO REPORTADO  SECUNDARIA  COLOMBIA
#
#        CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 4041    19256000.0             1970.0  10-048        aitufn1227@gmail.com
# 3810     5656000.0             1990.0  10-048  ibbcpu2509@unidatos.edu.co
# 693      5642000.0               57.0  10-079  unhoqj1172@unidatos.edu.co
# 10796   76001000.0             1994.0  10-079  iknnoj8430@unidatos.edu.co
# 2386    50287000.0             1973.0  10-255  afompq7113@unidatos.edu.co
# 138     19760000.0             1993.0  10-255  cobgqs8819@unidatos.edu.co

# %% [markdown]
# <span style="color:red">TODO: Delete records with "CÉDULA" duplicated</span>
#
# <span style="color:red">Hint: You can use drop_duplicates() pandas function.</span>

# %%
homicides_df.drop_duplicates(subset=['CÉDULA'], keep='first', inplace=True)

# %%
# Checking one of the duplicates cases
homicides_df[homicides_df["CÉDULA"] == "10-048"]
# Out:
#                    FECHA DEPARTAMENTO     MUNICIPIO      DIA    BARRIO  \
# 3810 2021-04-26 03:00:00    ANTIOQUIA  SAN JERÓNIMO  Domingo  LA PLAYA
#
#         ZONA                      CLASE DE SITIO        ARMA O MEDIO  \
# 3810  URBANA  HOTELES, RESIDENCIAS, Y SIMILARES.  CUERDA/SOGA/CADENA
#
#      MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL CLASE EMPLEADO  \
# 3810         A PIE         A PIE  25.0  MASCULINO      SOLTERO  INDEPENDIENTE
#
#          PROFESION ESCOLARIDAD PAIS NACE  CODIGO DANE  AÑO DE NACIMIENTO  \
# 3810  NO REPORTADO  SECUNDARIA  COLOMBIA    5656000.0             1990.0
#
#       CÉDULA                      CORREO
# 3810  10-048  ibbcpu2509@unidatos.edu.co

# %%
# Using regular expressions for validating if "CÉDULA" values match the pattern XX-XXX
cedula_malformed = homicides_df.loc[homicides_df["CÉDULA"].apply(lambda x: (re.match("\d{2}-\d{3}", x) is None))]

# %%
cedula_malformed.shape
# Out:
# (28, 21)

# %%
cedula_malformed.head(6)
# Out:
#                    FECHA DEPARTAMENTO          MUNICIPIO      DIA  \
# 172  2021-01-03 11:00:00         META            MESETAS   Sábado
# 1114 2021-02-01 12:30:00    ATLÁNTICO  BARRANQUILLA (CT)  Domingo
# 2119 2021-03-06 15:30:00        VALLE          CALI (CT)  Viernes
# 3309 2021-04-11 10:30:00      CAQUETÁ     FLORENCIA (CT)   Sávado
# 3409 2021-04-13 23:20:00      CÓRDOBA            SAHAGÚN    Lunes
# 3588 2021-04-19 20:00:00      BOLÍVAR     CARTAGENA (CT)  Domingo
#
#                             BARRIO    ZONA         CLASE DE SITIO  \
# 172                VEREDA EL CAFRE   RURAL         ZONA SELVÁTICA
# 1114                        LA LUZ  URBANA          VIAS PUBLICAS
# 2119           QUINTAS DEL SOL E14  URBANA  DENTRO DE LA VIVIENDA
# 3309                   VIA MORELIA   RURAL               CARCELES
# 3409  CORREGIMIENTO DE BAJO GRANDE  URBANA               BILLARES
# 3588                  LA ESPERANZA  URBANA          VIAS PUBLICAS
#
#           ARMA O MEDIO MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO  \
# 172   MINA ANTIPERSONA         A PIE         A PIE  24.0  MASCULINO
# 1114     ARMA DE FUEGO         A PIE         A PIE  29.0  MASCULINO
# 2119       ARMA BLANCA         A PIE         A PIE  20.0   FEMENINO
# 3309         CORTANTES         A PIE         A PIE  23.0  MASCULINO
# 3409      CONTUNDENTES         A PIE         A PIE  49.0  MASCULINO
# 3588     ARMA DE FUEGO         A PIE         A PIE  45.0  MASCULINO
#
#      ESTADO CIVIL       CLASE EMPLEADO     PROFESION   ESCOLARIDAD  \
# 172       SOLTERO    EMPLEADO EJERCITO  NO REPORTADO    SECUNDARIA
# 1114      SOLTERO        INDEPENDIENTE  NO REPORTADO      PRIMARIA
# 2119  UNION LIBRE  EMPLEADO PARTICULAR  NO REPORTADO    SECUNDARIA
# 3309      SOLTERO        INDEPENDIENTE  NO REPORTADO      PRIMARIA
# 3409      SOLTERO        INDEPENDIENTE  NO REPORTADO    SECUNDARIA
# 3588      SOLTERO          DESEMPLEADO  NO REPORTADO  NO REPORTADO
#
#          PAIS NACE  CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA  \
# 172       COLOMBIA   50330000.0             1991.0  680-21
# 1114      COLOMBIA    8001000.0             1986.0  140-17
# 2119      COLOMBIA   76001000.0             1995.0  975-31
# 3309      COLOMBIA   18001000.0             1992.0  348-66
# 3409      COLOMBIA   23660000.0             1966.0  496-18
# 3588  NO REPORTADO   13001000.0             1970.0  188-03
#
#                           CORREO
# 172         oohghd8899@gmail.com
# 1114  correo5853@colombia.gov.co
# 2119  ohbqrk3631@unidatos.edu.co
# 3309  pdkqur8407@unidatos.edu.co
# 3409  fdbbeo6751@unidatos.edu.co
# 3588  diebuo5651@unidatos.edu.co

# %% [markdown]
# <span style="color:red">TODO: Fix the malformed "CÉDULA" values.</span>

# %%
cedula_fixed = cedula_malformed.CÉDULA.apply(lambda x: x.replace("-","")[:2] + "-" + x.replace("-","")[2:])
cedula_fixed
# Out:
# 172      68-021
# 1114     14-017
# 2119     97-531
# 3309     34-866
# 3409     49-618
# 3588     18-803
# 4565     92-874
# 4587     27-345
# 4971     55-963
# 5372     63-185
# 5532     98-100
# 5834     31-949
# 5849     47-307
# 6315     89-381
# 7885     85-455
# 8094     60-436
# 8183     35-223
# 8223     58-651
# 9033     57-014
# 9751     51-841
# 10205    42-472
# 10625    85-267
# 10689    40-311
# 10959    50-205
# 11020    52-937
# 11740    86-483
# 11957    85-604
# 12206    12-861
# Name: CÉDULA, dtype: object

# %%
# Updating main dataframe with the fixes in CEDULA field
homicides_df.update(cedula_fixed)

# %% [markdown]
# <span style="color:red">TODO: Make something similar to check and fix the "CORREO" column (PATTERN: 4 digits before the @, only .edu.co and .com domains are allowed)</span>

# %%
correo_malformed = homicides_df.loc[homicides_df["CORREO"].apply(lambda x: (re.match("([1-9|a-z|A-Z]+)(\d{4}@)([1-9|a-z|A-Z]+)(\.[edu]{3}\.[co]{2}|\.[com]{3})", x) is None))]

# %%
correo_malformed.shape
# Out:
# (2134, 21)

# %%
correo_malformed.head(5)
# Out:
#                  FECHA  DEPARTAMENTO            MUNICIPIO     DIA  \
# 28 2021-01-01 15:00:00       CAQUETÁ  SAN JOSÉ DEL FRAGUA  Jueces
# 36 2021-01-01 08:00:00         CAUCA                PATÍA  Jueves
# 47 2021-01-01 09:00:00         CHOCÓ                 TADÓ  Jueves
# 55 2021-01-01 01:30:00  CUNDINAMARCA     BOGOTÁ D.C. (CT)  Jueves
# 60 2021-01-01 09:50:00  CUNDINAMARCA     BOGOTÁ D.C. (CT)  Jueves
#
#                        BARRIO    ZONA CLASE DE SITIO   ARMA O MEDIO  \
# 28                     CENTRO  URBANA     DISCOTECAS  ARMA DE FUEGO
# 36     C/MIENTO PIEDRASENTADA   RURAL      CARRETERA  ARMA DE FUEGO
# 47                    POPULAR  URBANA  VIAS PUBLICAS  ARMA DE FUEGO
# 55  ÁLVARO BERNAL SEGURA E-19  URBANA  VIAS PUBLICAS  ARMA DE FUEGO
# 60           LAS COLINAS E-18  URBANA  VIAS PUBLICAS    ARMA BLANCA
#
#    MOVIL VICTIMA MOVIL AGRESOR  EDAD     GENERO ESTADO CIVIL  \
# 28         A PIE         A PIE  24.0  MASCULINO  UNION LIBRE
# 36      VEHICULO         A PIE  26.0  MASCULINO      SOLTERO
# 47         A PIE         A PIE  34.0  MASCULINO       CASADO
# 55         A PIE         A PIE  25.0  MASCULINO  UNION LIBRE
# 60         A PIE         A PIE  37.0  MASCULINO      SOLTERO
#
#        CLASE EMPLEADO     PROFESION ESCOLARIDAD PAIS NACE  CODIGO DANE  \
# 28      INDEPENDIENTE  NO REPORTADO    PRIMARIA  COLOMBIA   18610000.0
# 36  EMPLEADO EJERCITO  NO REPORTADO  SECUNDARIA  COLOMBIA   19532000.0
# 47  EMPLEADO POLICIAL       POLICIA     TECNICO  COLOMBIA   27787000.0
# 55        DESEMPLEADO  NO REPORTADO  SECUNDARIA  COLOMBIA   11001000.0
# 60      INDEPENDIENTE  NO REPORTADO  SECUNDARIA  COLOMBIA   11001000.0
#
#     AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 28             1991.0  94-565   correo975@unidatos.edu.co
# 36             1989.0  69-084  correo4714@colombia.gov.co
# 47             1981.0  29-957  correo8297@colombia.gov.co
# 55             1990.0  35-260  correo7285@colombia.gov.co
# 60             1978.0  96-322   correo870@unidatos.edu.co

# %%
def fix_email(fixed):
    if(fixed == ""):
        fixed = "dummy1234@dummy.com"
    else:
        splitted = fixed.split(".")
        # Checking if is "edu.co"
        if (splitted[-1] == "co") and (splitted[-2] == "gov"):
            splitted[-2] = "edu"
            fixed = ".".join(splitted)

        splitted = fixed.split("@")
        count = sum(c.isdigit() for c in splitted[0])
        # Checking if has 4 numbers
        if (count < 4):
            # Duplicating the last number
            for i in range (count, 4, 1):
                splitted[0] = splitted[0] + splitted[0][-1]
                fixed = "@".join(splitted)
    return fixed

# %%
correo_fixed = correo_malformed["CORREO"].apply(lambda x: fix_email(x))

# %%
correo_fixed.head()
# Out:
# 28    correo9755@unidatos.edu.co
# 36    correo4714@colombia.edu.co
# 47    correo8297@colombia.edu.co
# 55    correo7285@colombia.edu.co
# 60    correo8700@unidatos.edu.co
# Name: CORREO, dtype: object

# %%
# Updating the CORREO field with the fixes
homicides_df.update(correo_fixed)

# %%
# Showing different values for "DIA" column
homicides_df["DIA"].unique()
# Out:
# array(['Jueves', 'Juees', 'Jueces', 'juves', 'Juevrs', 'Viernes',
#        'Viermes', 'iernes', 'virnes', 'Vierens', 'Sábado', 'Sabadi',
#        'Sabado', 'sábad', 'Sávado', 'Ssbado', 'Domingo', 'Domungo',
#        'Doningo', 'domungo', 'Lunes', 'lune', 'Luns', 'Lumes', 'kunes',
#        'Lnues', 'Martes', 'Mates', 'Marte', 'mates', 'Miércoles',
#        'Miwrcoles', 'Mircoles', 'Voernes', 'domnigo', 'Maryes',
#        'Miercoles', 'miércles', 'Dominog', 'Msrtes', 'Mirrcoles'],
#       dtype=object)

# %%
# Calculating the distance between two words using the Levenshtein method
pylev.levenshtein('sábado', 'sabaod')
# Out:
# 3

# %%
pylev.levenshtein('sábado', 'viernes')
# Out:
# 7

# %%
pylev.levenshtein('sábado', 'sabado')
# Out:
# 1

# %% [markdown]
# <span style="color:red">TODO: Create a function to fix the digitation errors for "DIA" column.</span>

# %%
def fix_day_name(day_name):
    # The max distance in the week day names is 9
    distance = 9
    day_fix = ""
    days_names_list = ["Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado", "Domingo"]
    # Comparing the day_name with all possible names in the list
    for day in days_names_list:
        num = pylev.levenshtein(day, day_name)
        # Assigning the lowest distance (more accurate name)
        if (num < distance):
            distance = num
            day_fix = day
    return day_fix

# %%
dia = fix_day_name("iernes")
print(dia)
# Out:
# Viernes

# %%
homicides_df["DIA"] = homicides_df["DIA"].apply(lambda x: fix_day_name(x))

# %%
homicides_df["DIA"].unique()
# Out:
# array(['Jueves', 'Lunes', 'Viernes', 'Sábado', 'Domingo', 'Martes',
#        'Miércoles'], dtype=object)

# %%
homicides_df[["AÑO DE NACIMIENTO", "EDAD"]].head(10)
# Out:
#    AÑO DE NACIMIENTO  EDAD
# 0             1971.0  44.0
# 1             1985.0  30.0
# 2             1982.0  33.0
# 3             1975.0  40.0
# 4             1949.0  66.0
# 5             1973.0  42.0
# 6             1990.0  25.0
# 7             1978.0  37.0
# 8             1990.0  25.0
# 9             1985.0  30.0

# %% [markdown]
# <span style="color:red">TODO: Fix the "AÑO DE NACIMIENTO" column using the column "EDAD".</span>

# %%
current_year = datetime.now().year

homicides_df["AÑO DE NACIMIENTO"] = homicides_df["EDAD"].apply(lambda x: current_year - x)

# %%
homicides_df[["AÑO DE NACIMIENTO", "EDAD"]].head(10)
# Out:
#    AÑO DE NACIMIENTO  EDAD
# 0             1978.0  44.0
# 1             1992.0  30.0
# 2             1989.0  33.0
# 3             1982.0  40.0
# 4             1956.0  66.0
# 5             1980.0  42.0
# 6             1997.0  25.0
# 7             1985.0  37.0
# 8             1997.0  25.0
# 9             1992.0  30.0

# %%
homicides_df.head(10)
# Out:
#                 FECHA DEPARTAMENTO      MUNICIPIO     DIA  \
# 0 2021-01-01 06:00:00    ANTIOQUIA          AMAGÁ  Jueves
# 1 2021-01-01 09:00:00    ANTIOQUIA        BARBOSA  Jueves
# 2 2021-01-01 19:00:00    ANTIOQUIA       EL BAGRE  Jueves
# 3 2021-01-01 11:20:00    ANTIOQUIA         JARDÍN  Jueves
# 4 2021-01-01 15:00:00    ANTIOQUIA  MEDELLÍN (CT)  Jueves
# 5 2021-01-01 00:47:00    ANTIOQUIA  MEDELLÍN (CT)  Jueves
# 6 2021-01-01 11:00:00    ANTIOQUIA  MEDELLÍN (CT)  Jueves
# 7 2021-01-01 19:35:00    ANTIOQUIA  MEDELLÍN (CT)  Jueves
# 8 2021-01-01 20:35:00    ANTIOQUIA  MEDELLÍN (CT)  Jueves
# 9 2021-01-01 14:00:00    ANTIOQUIA         MUTATÁ  Jueves
#
#                        BARRIO    ZONA                      CLASE DE SITIO  \
# 0                   EL VOLCAN   RURAL                              TIENDA
# 1              VDA. MATASANOS   RURAL                       VIAS PUBLICAS
# 2               PUERTO CLAVER   RURAL                  FINCAS Y SIMILARES
# 3                  CRISTIANIA   RURAL                  FINCAS Y SIMILARES
# 4    PICACHITO CNO REPORTADO6  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# 5      CORDOBA CNO REPORTADO7  URBANA                       VIAS PUBLICAS
# 6  CRISTO REY CNO REPORTADO15  URBANA                       VIAS PUBLICAS
# 7    LA SALLE  CNO REPORTADO3  URBANA                       VIAS PUBLICAS
# 8      KENNEDY CNO REPORTADO6  URBANA                       VIAS PUBLICAS
# 9               VDA CASA ROJA   RURAL                  FINCAS Y SIMILARES
#
#     ARMA O MEDIO MOVIL VICTIMA         MOVIL AGRESOR  EDAD     GENERO  \
# 0    ARMA BLANCA         A PIE                 A PIE  44.0  MASCULINO
# 1    ARMA BLANCA         A PIE                 A PIE  30.0  MASCULINO
# 2    ARMA BLANCA         A PIE                 A PIE  33.0  MASCULINO
# 3    ARMA BLANCA         A PIE                 A PIE  40.0  MASCULINO
# 4   CONTUNDENTES         A PIE                 A PIE  66.0  MASCULINO
# 5  ARMA DE FUEGO         A PIE                 A PIE  42.0  MASCULINO
# 6    ARMA BLANCA         A PIE                 A PIE  25.0  MASCULINO
# 7    ARMA BLANCA         A PIE                 A PIE  37.0  MASCULINO
# 8  ARMA DE FUEGO         A PIE  PASAJERO MOTOCICLETA  25.0  MASCULINO
# 9    ARMA BLANCA         A PIE                 A PIE  30.0  MASCULINO
#
#   ESTADO CIVIL  CLASE EMPLEADO     PROFESION ESCOLARIDAD     PAIS NACE  \
# 0       CASADO   INDEPENDIENTE  NO REPORTADO    PRIMARIA      COLOMBIA
# 1      SOLTERO     DESEMPLEADO  NO REPORTADO  SECUNDARIA  NO REPORTADO
# 2  UNION LIBRE      AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 3       CASADO      AGRICULTOR  NO REPORTADO    PRIMARIA      COLOMBIA
# 4  UNION LIBRE     DESEMPLEADO  NO REPORTADO    PRIMARIA      COLOMBIA
# 5      SOLTERO   INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 6      SOLTERO     DESEMPLEADO  NO REPORTADO  SECUNDARIA      COLOMBIA
# 7       CASADO   INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 8      SOLTERO   INDEPENDIENTE  NO REPORTADO  SECUNDARIA      COLOMBIA
# 9      SOLTERO  ETNIA INDIGENA  NO REPORTADO  SECUNDARIA  NO REPORTADO
#
#    CODIGO DANE  AÑO DE NACIMIENTO  CÉDULA                      CORREO
# 0    5030000.0             1978.0  42-908  agbnqg2122@unidatos.edu.co
# 1    5079000.0             1992.0  15-183        rbkeui3584@gmail.com
# 2    5250000.0             1989.0  84-786  aorkhf9155@unidatos.edu.co
# 3    5364000.0             1982.0  31-289  dhtemr6623@unidatos.edu.co
# 4    5001000.0             1956.0  66-363  artatj9268@unidatos.edu.co
# 5    5001000.0             1980.0  54-450  grlcsj8696@unidatos.edu.co
# 6    5001000.0             1997.0  45-052        pkdakc6682@gmail.com
# 7    5001000.0             1985.0  45-298        qledtq1884@gmail.com
# 8    5001000.0             1997.0  37-281  mipgfg2758@unidatos.edu.co
# 9    5480000.0             1992.0  78-013  dgepmg5536@unidatos.edu.co
